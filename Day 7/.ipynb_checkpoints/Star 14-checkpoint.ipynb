# %%
Answers = open('ExAnswers.txt').read().split('\n')
Numbers = open('ExNumbers.txt').read().split('\n')
for i in range(len(Answers)):
    Answers[i] = int(Answers[i])

for i in range(len(Numbers)):
    Numbers[i] = Numbers[i].split()

ConAnswers = []
ConNumbers = []
newbank = []
for i in range(len(Answers)):
    ThisAns = Answers[i]
    TheseNums = Numbers[i]
    bank = []
    for n in range(len(TheseNums)-1):
        TempNum = bank.copy()
        print('TempNum:', TempNum)
        bank.clear()
        if n == 0:
            TempNum.append([TheseNums[0]])
        print('TempNum:', TempNum)
        print(bank)
        
        for m in range(len(TempNum)):
            print(str(TempNum).strip('[\']').replace(']', '').replace(',', '').replace(',', '').replace('[', '').replace('\'', ''))
            bank.append([str(TempNum[m]).strip('[\']').strip('[\']').replace(']', '').replace(',', '').replace(',', '').replace('[', '').replace('\'', '') + TheseNums[n+1]])
            print([str(TempNum[m]).strip('[\']').replace(']', '').replace(',', '').replace(',', '').replace('[', '').replace('\'', '') + TheseNums[n+1]])
            bank.append([str(TempNum[m]).strip('[\']').replace(']', '').replace(',', '').replace(',', '').replace('[', '').replace('\'', ''), TheseNums[n+1]])
            print([str(TempNum[m]).strip('[\']').replace(']', '').replace(',', '').replace(',', '').replace('[', '').replace('\'', ''), TheseNums[n+1]])
            print(bank)
            print(ConNumbers)
            newbank = bank.copy()
            ConAnswers.append(ThisAns)
    ConNumbers.extend(newbank)
    print('ConNumbers:', ConNumbers)
    ConAnswers.append(ThisAns)
            
        
print(ConAnswers)

print(ConNumbers)
for i in range(len(ConNumbers)):
    for n in range(len(ConNumbers[i])):
        if ConNumbers[i][n].count(' ') != 0:
            TempNum2 = str(ConNumbers[i].copy()).strip('\'[,]').replace(']', '').replace(',', '').replace(',', '').replace('[', '').replace('\'', '').split(' ')
            print('\nLooking at this:', ConNumbers[i])
            ConNumbers.pop(i)
            print(TempNum2)
            ConNumbers.insert(i, TempNum2)
        print(ConNumbers, '\n')

for i in range(len(ConNumbers)):
    for n in range(len(ConNumbers[i])):        
        ConNumbers[i][n] = int(ConNumbers[i][n])

print('ConNumbers:', ConNumbers)
print('ConAnswers:', ConAnswers)
print('ConNumbers:', len(ConNumbers))
print('ConAnswers:', len(ConAnswers))

total = 0
for i in range(len(ConAnswers)):
    ThisAns = ConAnswers[i]
    TheseNums = ConNumbers[i]
    if TheseNums == [6, 86, 15]:
        print('[6, 86, 15]')
    bank = []
    for n in range(len(TheseNums)-1):
        if n == 0:
            bank.append(TheseNums[n])
        TempNum = bank.copy()
        bank.clear()
        for m in range(len(TempNum)):
            bank.append(TempNum[m] + TheseNums[n+1])
            bank.append(TempNum[m] * TheseNums[n+1])
            if TheseNums == [6, 86, 15]:
                print(bank)
    
    if bank.count(ThisAns) != 0 or TheseNums[0] == ThisAns:
        print(ThisAns, ':', bank, ':', TheseNums)
        total += ThisAns
            
print(total)

# %%
Answers = open('Answers.txt').read().split('\n')
for i in range(len(Answers)):
    Answers[i] = int(Answers[i])
Numbers = open('Numbers.txt').read().split('\n')
for i in range(len(Numbers)):
    Numbers[i] = Numbers[i].split()
    for n in range(len(Numbers[i])):
        Numbers[i][n] = int(Numbers[i][n])

total = 0
for i in range(len(Answers)):
    ThisAns = Answers[i]
    TheseNums = Numbers[i]
    bank = []
    Equal = False
    for n in range(len(TheseNums)-1):
        if n == 0:
            bank.append(TheseNums[n])
        TempNum = bank.copy()
        bank.clear()
        for m in range(len(TempNum)):
            bank.append(TempNum[m] + TheseNums[n+1])
            bank.append(TempNum[m] * TheseNums[n+1])
            bank.append(int(str(TempNum[m]) + str(TheseNums[n+1])))
    if bank.count(ThisAns) != 0:
        #print(ThisAns, ':', bank)
        total += ThisAns
            
print(total)
# Out:
# 328790210468594
