# %%
StartStones = open('Start Numbers.txt').read().split(' ')

for i in range(len(StartStones)):
    StartStones[i] = int(StartStones[i])

for n in range(0, 25):
    if n == 0:
        ThisGo = StartStones.copy()
    else:
        ThisGo = NewStones.copy()
    NewStones = []
    for i in range(len(ThisGo)):
        if ThisGo[i] == 0:
            NewStones.append(1)
        elif len(str(ThisGo[i])) % 2 == 0:
            TempS = str(ThisGo[i])
            TempS1 = TempS[0:len(TempS)//2]
            #print(TempS1)
            TempS2 = TempS[len(TempS)//2:]
            #print(TempS2)
            NewStones.append(int(TempS1))
            NewStones.append(int(TempS2))
        else:
            NewStones.append(ThisGo[i]*2024)

print(NewStones)
print(len(NewStones))
# Out:
# [4048, 8096, 10120, 14168, 18216, 8096, 10120, 12144, 40, 48, 2024, 40, 48, 80, 96, 4048, 16192, 12144, 14168, 12144, 1, 6072, 4048, 8, 0, 9, 6, 20, 24, 8, 0, 9, 6, 3277, 2608, 3277, 2608, 20, 24, 3686, 9184, 2457, 9456, 40, 48, 2024, 40, 48, 80, 96, 3277, 2608, 20, 24, 3686, 9184, 2457, 9456, 6072, 4048, 14168, 14168, 4048, 12144, 32772608, 8096, 1, 8096, 16192, 32, 77, 26, 8, 24, 57, 94, 56, 28, 67, 60, 32, 24, 57, 94, 56, 2, 0, 2, 4, 12144, 1, 14168, 4048, 8096, 1, 8096, 16192, 8096, 1, 8096, 16192, 32, 77, 26, 8, 24, 57, 94, 56, 28, 67, 60, 32, 24, 57, 94, 56, 2, 0, 2, 4, 12144, 1, 14168, 4048, 8096, 1, 8096, 16192, 3277, 2608, 20, 24, 3686, 9184, 2457, 9456, 40, 48, 2024, 40, 48, 80, 96, 3277, 2608, 20, 24, 3686, 9184, 2457, 9456, 6072, 4048, 14168, 14168, 4048, 12144, 32772608, 8096, 1, 8096, 16192, 16192, 1, 18216, 12144, 20, 48, 28, 80, 28, 67, 60, 32, 36, 86, 91, 84, 16192, 1, 18216, 12144, 20, 48, 28, 80, 24, 57, 94, 56, 24579456, 2024, 28676032, 40, 48, 80, 96, 2024, 80, 96, 32772608, 2, 8, 6, 7, 6, 0, 3, 2, 2, 8, 6, 7, 6, 0, 3, 2, 80, 96, 2024, 80, 96, 32772608, 2, 4, 5, 7, 9, 4, 5, 6, 6072, 4048, 14168, 14168, 4048, 12144, 32772608, 32, 77, 26, 8, 2, 0, 2, 4, 36, 86, 91, 84, 24, 57, 94, 56, 4, 0, 4, 8, 20, 24, 4, 0, 4, 8, 8, 0, 9, 6, 32, 77, 26, 8, 2, 0, 2, 4, 36, 86, 91, 84, 24, 57, 94, 56, 60, 72, 40, 48, 28676032, 28676032, 40, 48, 24579456, 3277, 2608, 8, 0, 9, 6, 20, 24, 8, 0, 9, 6, 3277, 2608, 40, 48, 2024, 40, 48, 80, 96, 8, 0, 9, 6, 20, 24, 8, 0, 9, 6, 3277, 2608, 3277, 2608, 20, 24, 3686, 9184, 2457, 9456,
 3277, 2608, 20, 24, 3686, 9184, 2457, 9456, 40, 48, 2024, 40, 48, 80, 96, 3277, 2608, 20, 24, 3686, 9184, 2457, 9456, 6072, 4048, 14168, 14168, 4048, 12144, 32772608, 6072, 4048, 14168, 14168, 4048, 12144, 32772608, 40, 48, 2024, 40, 48, 80, 96, 6072, 12144, 16192, 12144, 18216, 2024, 16192, 8096, 4048, 8096, 10120, 14168, 18216, 8096, 10120, 12144, 8096, 1, 8096, 16192, 2, 0, 2, 4, 16192, 1, 18216, 12144, 32, 77, 26, 8, 8096, 1, 8096, 16192, 32, 77, 26, 8, 32, 77, 26, 8, 2, 0, 2, 4, 8096, 1, 8096, 16192, 32, 77, 26, 8, 24, 57, 94, 56, 28, 67, 60, 32, 24, 57, 94, 56, 2, 0, 2, 4, 12144, 1, 14168, 4048, 8096, 1, 8096, 16192, 12144, 1, 14168, 4048, 24, 57, 94, 56, 32, 77, 26, 8, 24, 57, 94, 56, 36, 86, 91 ...
# 220999

# %%
for n0 in range(0, 75):
    if n0 == 0:
        ThisGo0 = num0.copy()
    else:
        ThisGo0 = NewStones0.copy()
    NewStones0 = []
    for i0 in range(len(ThisGo0)):
        if ThisGo0[i0] == 0:
            NewStones0.append(1)
        elif len(str(ThisGo0[i0])) % 2 == 0:
            TempS0 = str(ThisGo0[i0])
            TempS10 = TempS0[0:len(TempS0)//2]
            TempS20 = TempS0[len(TempS0)//2:]
            NewStones0.append(int(TempS10))
            NewStones0.append(int(TempS20))
        else:
            NewStones0.append(ThisGo0[i0]*2024)

len0 = len(NewStones0)
print(len(NewStones0))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 11
#       9     NewStones0.append(1)
#      10 elif len(str(ThisGo0[i0])) % 2 == 0:
# ---> 11     TempS0 = str(ThisGo0[i0])
#      12     TempS10 = TempS0[0:len(TempS0)//2]
#      13     TempS20 = TempS0[len(TempS0)//2:]
#
# KeyboardInterrupt:

# %%
for n2 in range(0, 75):
    if n2 == 0:
        ThisGo1 = num2.copy()
    else:
        ThisGo2 = NewStones2.copy()
    NewStones2 = []
    for i2 in range(len(ThisGo2)):
        if ThisGo2[i2] == 0:
            NewStones2.append(1)
        elif len(str(ThisGo2[i2])) % 2 == 0:
            TempS2 = str(ThisGo2[i2])
            TempS12 = TempS2[0:len(TempS2)//2]
            #print(TempS1)
            TempS22 = TempS2[len(TempS2)//2:]
            #print(TempS2)
            NewStones2.append(int(TempS12))
            NewStones2.append(int(TempS22))
        else:
            NewStones2.append(ThisGo2[i2]*2024)

len2 = len(NewStones2)
print(len(NewStones2))

# %%
for n3 in range(0, 75):
    if n3 == 0:
        ThisGo3 = num3.copy()
    else:
        ThisGo3 = NewStones3.copy()
    NewStones3 = []
    for i3 in range(len(ThisGo3)):
        if ThisGo1[i3] == 0:
            NewStones3.append(1)
        elif len(str(ThisGo1[i3])) % 2 == 0:
            TempS3 = str(ThisGo3[i3])
            TempS13 = TempS3[0:len(TempS3)//2]
            #print(TempS1)
            TempS23 = TempS3[len(TempS3)//2:]
            #print(TempS2)
            NewStones3.append(int(TempS13))
            NewStones3.append(int(TempS23))
        else:
            NewStones3.append(ThisGo3[i3]*2024)

len3 = len(NewStones3)
print(len(NewStones3))

# %%
for n4 in range(0, 75):
    if n4 == 0:
        ThisGo4 = num4.copy()
    else:
        ThisGo4 = NewStones4.copy()
    NewStones4 = []
    for i4 in range(len(ThisGo4)):
        if ThisGo1[i4] == 0:
            NewStones4.append(1)
        elif len(str(ThisGo4[i4])) % 2 == 0:
            TempS4 = str(ThisGo4[i4])
            TempS14 = TempS4[0:len(TempS4)//2]
            #print(TempS1)
            TempS24 = TempS4[len(TempS4)//2:]
            #print(TempS2)
            NewStones4.append(int(TempS14))
            NewStones4.append(int(TempS24))
        else:
            NewStones4.append(ThisGo4[i4]*2024)

len4 = len(NewStones4)
print(len(NewStones4))

# %%
for n5 in range(0, 75):
    if n5 == 0:
        ThisGo5 = num5.copy()
    else:
        ThisGo5 = NewStones5.copy()
    NewStones5 = []
    for i5 in range(len(ThisGo5)):
        if ThisGo5[i5] == 0:
            NewStones5.append(1)
        elif len(str(ThisGo5[i5])) % 2 == 0:
            TempS5 = str(ThisGo5[i5])
            TempS15 = TempS5[0:len(TempS5)//2]
            #print(TempS1)
            TempS25 = TempS5[len(TempS5)//2:]
            #print(TempS2)
            NewStones5.append(int(TempS15))
            NewStones5.append(int(TempS25))
        else:
            NewStones5.append(ThisGo5[i5]*2024)

len5 = len(NewStones5)
print(len(NewStones5))

# %%
for n6 in range(0, 75):
    if n6 == 0:
        ThisGo6 = num6.copy()
    else:
        ThisGo6 = NewStones6.copy()
    NewStones6 = []
    for i6 in range(len(ThisGo6)):
        if ThisGo6[i6] == 0:
            NewStones6.append(1)
        elif len(str(ThisGo6[i6])) % 2 == 0:
            TempS6 = str(ThisGo6[i6])
            TempS16 = TempS6[0:len(TempS6)//2]
            #print(TempS1)
            TempS26 = TempS6[len(TempS6)//2:]
            #print(TempS2)
            NewStones6.append(int(TempS16))
            NewStones6.append(int(TempS26))
        else:
            NewStones6.append(ThisGo6[i6]*2024)

len6 = len(NewStones6)
print(len(NewStones6))

# %%
for n7 in range(0, 75):
    if n7 == 0:
        ThisGo7 = num7.copy()
    else:
        ThisGo7 = NewStones7.copy()
    NewStones7 = []
    for i7 in range(len(ThisGo7)):
        if ThisGo1[i7] == 0:
            NewStones7.append(1)
        elif len(str(ThisGo7[i7])) % 2 == 0:
            TempS7 = str(ThisGo7[i7])
            TempS17 = TempS7[0:len(TempS7)//2]
            #print(TempS1)
            TempS27 = TempS7[len(TempS7)//2:]
            #print(TempS2)
            NewStones7.append(int(TempS17))
            NewStones7.append(int(TempS27))
        else:
            NewStones7.append(ThisGo7[i7]*2024)

len7 = len(NewStones7)
print(len(NewStones7))
